# %%
# Importing Required Libraries

import os
import pandas as pd
import numpy as np
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D

# %%
# Create Directory for train and test 
TRAIN_DIR = 'images/train'
TEST_DIR ='images/test'

# %%
# Create function to create dataframe for images
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
# Creating dataframe for train
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
# Creating dataframe for test
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]

# %%
print(test)
print(test['image'])
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]
# 0         images/test\angry\10052.jpg
# 1         images/test\angry\10065.jpg
# 2         images/test\angry\10079.jpg
# 3         images/test\angry\10095.jpg
# 4         images/test\angry\10121.jpg
#                     ...
# 7061    images/test\surprise\9806.jpg
# 7062    images/test\surprise\9830.jpg
# 7063    images/test\surprise\9853.jpg
# 7064    images/test\surprise\9878.jpg
# 7065     images/test\surprise\993.jpg
# Name: image, Length: 7066, dtype: object

# %%
from tqdm.notebook import tqdm

# %%
from tqdm import tqdm
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np

def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image)
        img = img.convert('L')  # Convert to grayscale
        img = img_to_array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
test_features = extract_features(train['image'])
# Out:
# 100%|██████████| 28821/28821 [01:05<00:00, 437.17it/s]

# %%
train_features = extract_features(train['image'])
# Out:
# 100%|██████████| 28821/28821 [00:17<00:00, 1650.07it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))
# Out:
# c:\Users\A\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import numpy as np
from sklearn.model_selection import train_test_split

assert len(x_train) == len(y_train), "x_train and y_train must have the same number of samples"



# Split your data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 324s 2s/step - accuracy: 0.2306 - loss: 1.8396 - val_accuracy: 0.2614 - val_loss: 1.8087
# Epoch 2/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 298s 2s/step - accuracy: 0.2505 - loss: 1.8058 - val_accuracy: 0.2654 - val_loss: 1.7729
# Epoch 3/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 311s 2s/step - accuracy: 0.2685 - loss: 1.7528 - val_accuracy: 0.3284 - val_loss: 1.6606
# Epoch 4/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 316s 2s/step - accuracy: 0.3326 - loss: 1.6654 - val_accuracy: 0.4269 - val_loss: 1.5230
# Epoch 5/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 1516s 8s/step - accuracy: 0.3874 - loss: 1.5526 - val_accuracy: 0.4503 - val_loss: 1.4251
# Epoch 6/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 295s 2s/step - accuracy: 0.4244 - loss: 1.4813 - val_accuracy: 0.4753 - val_loss: 1.3619
# Epoch 7/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.4451 - loss: 1.4333 - val_accuracy: 0.4958 - val_loss: 1.3358
# Epoch 8/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.4639 - loss: 1.3988 - val_accuracy: 0.5030 - val_loss: 1.2958
# Epoch 9/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.4687 - loss: 1.3770 - val_accuracy: 0.5159 - val_loss: 1.2583
# Epoch 10/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.4921 - loss: 1.3162 - val_accuracy: 0.5098 - val_loss: 1.2712
# Epoch 11/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.4966 - loss: 1.3233 - val_accuracy: 0.5318 - val_loss: 1.2343
# Epoch 12/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.5052 - loss: 1.2909 - val_accuracy: 0.5303 - val_loss: 1.2189
# Epoch 13/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 271s 1s/step - accuracy: 0.5063 - loss: 1.2822 - val_accuracy: 0.5369 - val_loss: 1.2092
# Epoch 14/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.5194 - loss: 1.2552 - val_accuracy: 0.5412 - val_loss: 1.1899
# Epoch 15/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.5200 - loss: 1.2451 - val_accuracy: 0.5462 - val_loss: 1.1847
# Epoch 16/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 0.5368 - loss: 1.2262 - val_accuracy: 0.5561 - val_loss: 1.1703
# Epoch 17/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 0.5336 - loss: 1.2167 - val_accuracy: 0.5568 - val_loss: 1.1584
# Epoch 18/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 280s 2s/step - accuracy: 0.5353 - loss: 1.2102 - val_accuracy: 0.5627 - val_loss: 1.1481
# Epoch 19/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - accuracy: 0.5513 - loss: 1.1808 - val_accuracy: 0.5644 - val_loss: 1.1367
# Epoch 20/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - accuracy: 0.5532 - loss: 1.1756 - val_accuracy: 0.5592 - val_loss: 1.1529
# Epoch 21/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━
100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - accuracy: 0.7274 - loss: 0.7467 - val_accuracy: 0.6142 - val_loss: 1.0882
# Epoch 89/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 299s 2s/step - accuracy: 0.7270 - loss: 0.7472 - val_accuracy: 0.6132 - val_loss: 1.0787
# Epoch 90/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 331s 2s/step - accuracy: 0.7326 - loss: 0.7305 - val_accuracy: 0.6111 - val_loss: 1.0936
# Epoch 91/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 309s 2s/step - accuracy: 0.7306 - loss: 0.7327 - val_accuracy: 0.6163 - val_loss: 1.1072
# Epoch 92/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 297s 2s/step - accuracy: 0.7336 - loss: 0.7291 - val_accuracy: 0.6108 - val_loss: 1.0812
# Epoch 93/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 295s 2s/step - accuracy: 0.7413 - loss: 0.7254 - val_accuracy: 0.6069 - val_loss: 1.0973
# Epoch 94/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 300s 2s/step - accuracy: 0.7415 - loss: 0.7020 - val_accuracy: 0.6128 - val_loss: 1.0852
# Epoch 95/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 318s 2s/step - accuracy: 0.7450 - loss: 0.7035 - val_accuracy: 0.6114 - val_loss: 1.0987
# Epoch 96/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 322s 2s/step - accuracy: 0.7416 - loss: 0.7122 - val_accuracy: 0.6130 - val_loss: 1.0883
# Epoch 97/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 296s 2s/step - accuracy: 0.7370 - loss: 0.7081 - val_accuracy: 0.6127 - val_loss: 1.1005
# Epoch 98/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 301s 2s/step - accuracy: 0.7385 - loss: 0.7134 - val_accuracy: 0.6069 - val_loss: 1.0928
# Epoch 99/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 298s 2s/step - accuracy: 0.7467 - loss: 0.7021 - val_accuracy: 0.5997 - val_loss: 1.1086
# Epoch 100/100
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 300s 2s/step - accuracy: 0.7469 - loss: 0.7060 - val_accuracy: 0.6057 - val_loss: 1.1131

# %%
from keras.models import model_from_json

# %%
# Save the model architecture as JSON
model_json = model.to_json()
with open("facialemotionmodel.json", "w") as json_file:
    json_file.write(model_json)

# Save the model's weights and architecture together in HDF5 format
model.save("facialemotionmodel.keras")

# %%
from keras.models import model_from_json

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,grayscale =  True )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
# Importing Necessary Libraries
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import load_img

def load_and_preprocess_image(image_path):
    # Load the image in grayscale mode
    img = load_img(image_path, color_mode='grayscale', target_size=(48, 48), interpolation='nearest')
    # Convert the image to a numpy array and reshape it
    img_array = np.array(img).reshape((1, 48, 48, 1))
    return img_array

# Example usage
image_path = 'images/train/happy/7.jpg'
print("Original image is of happy")

# Load and preprocess the image
img = load_and_preprocess_image(image_path)

# Assuming `model` and `label` are defined elsewhere
# Perform prediction
pred = model.predict(img)
pred_label = label[pred.argmax()]

print("Model prediction is", pred_label)

# Display the grayscale image using Matplotlib
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title("Original Image")
plt.show()
# Out:
# Original image is of happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Model prediction is happy
